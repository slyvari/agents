# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace
from openai import OpenAI

# %%
load_dotenv(override=True)

# %%
agent = Agent(
  name="Neocortex",
  instructions="Your name is Neocortex, you are a helpful assistant that can help to recall things I forget and help with tasks.",
  model="gpt-4o-mini",
)
agent

# %%
with trace("Remind-me"):
  result = await Runner.run(agent, "Todays trival, Did you know...")
  print(result.final_output)
