# %%
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
import os
open_router_api_key = os.getenv('OPENROUTER_API_KEY')

if open_router_api_key:
    print(f"OpenRouter API Key exists and begins {open_router_api_key[:8]}")
else:
    print("OpenRouter API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenRouter API Key exists and begins sk-or-v1

# %%
# Use the OpenAI client library pointed at OpenRouter (see guides/09_ai_apis_and_ollama.ipynb)
from openai import OpenAI

OPENROUTER_BASE_URL = "https://openrouter.ai/api/v1"
openrouter = OpenAI(base_url=OPENROUTER_BASE_URL, api_key=open_router_api_key)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from openrouter import OpenRouter
#
# ModuleNotFoundError: No module named 'openrouter'
